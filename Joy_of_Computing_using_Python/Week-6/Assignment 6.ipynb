# %% [markdown]
# # Week 6: Assignment 6

# %% [markdown]
# *1) What is the output of following code:*
#
# ![image.png](attachment:image.png)
#
# - a) 14930352
# - b) 75025 ✅
# - c) 610
# - d) None of the above

# %% [markdown]
# *2) Which method in Python is used to convert lowercase letters in a string to uppercase?*
#
# - a) upper() ✅
# - b) capitalize()
# - c) casefold()
# - d) swapcase()

# %% [markdown]
# *3) The "Min Max" strategy, often referred to as the minimax algorithm, is a decision-making algorithm used in game theory and artificial intelligence. It's commonly employed in two-player games with alternate turns and perfect information, such as chess or tic-tac-toe. What is the primary objective of the min max algorithm?*
#
# - a) Maximizing the player's score
# - b) Minimizing the opponent's score
# - c) Minimizing the maximum possible loss ✅
# - d) Maximizing the number of moves

# %% [markdown]
# *4) Typecasting refers to the conversion of one data type to another. Python provides several built-in functions for typecasting, such as int(), float(), str(), list(), tuple(), set(), and dict() among others, to convert between different data types. What would be the output of the following code?*
#
# ![Screenshot%202024-02-20%20at%203.44.47%20PM.png](attachment:Screenshot%202024-02-20%20at%203.44.47%20PM.png)
#
# - a) 123
# - b) ValueError ✅
# - c) SyntaxError
# - d) NameError

# %% [markdown]
# *5) What term is used in programming languages when a function calls itself?*
#
# - a) Self-referencing
# - b) Iteration
# - c) Recursion ✅
# - d) Circular referencing

# %% [markdown]
# *6) Consider the following snippet of code.*
#
# ![Image%202.png](attachment:Image%202.png)
#
# *If L is a non-empty list of positive integers, which of the following statements is correct about the recursive function func(L)?*
#
# - a) It returns the total number of odd elements in the list L
# - b) It returns the total number of even elements in the list L ✅
# - c) It returns the sum of the even elements in the list L
# - d) It returns the sum of the odd elements in the list L

# %% [markdown]
# *7) Consider the following snippet of code.*
#
# ![image%203.png](attachment:image%203.png)
#
# *If L is a non-empty list of positive integers, which of the following statements is correct about the recursive function func(L)?*
#
# - a) It returns the total number of odd elements in the list L
# - b) It returns the total number of even elements in the list L
# - c) It returns the sum of the even elements in the list L
# - d) It returns sum of the odd elements in the list L ✅

# %% [markdown]
# *8) What purpose does a base case serve in recursive functions?*
#
# - a) To make the function run faster
# - b) To eliminate the need for additional functions
# - c) To prevent infinite recursion and ensure termination ✅
# - d) To enable the function to handle complex calculations

# %% [markdown]
# ### Q. 9-10

# %% [markdown]
# *Consider the following function f that accepts an integer as argument n.*
#
# ![Screenshot%202024-02-20%20at%203.57.22%20PM.png](attachment:Screenshot%202024-02-20%20at%203.57.22%20PM.png)
#
# *9) What is the value returned by f(10000) ?*
#
# *Answer:* **7** ✅

# %% [markdown]
# *10) What is the value returned by f(-8) ?*
#
# *Answer:* **5** ✅
